# %%
#Data Gathering
#EDA
#Feature Engineering
#Model Building__Supervised and Unsupervised Learning
#Evaluation or Validation of model

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df=pd.read_csv("googleplaystore.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.sample(10)
# Out:
#                                    App          Category  Rating  Reviews  \
# 4031     ZEDGE™ Ringtones & Wallpapers   PERSONALIZATION     4.6  6459626
# 5301                      AK Blackjack              GAME     NaN        4
# 10765  Chat For Strangers - Video Chat            SOCIAL     3.4      622
# 4056          Dream League Soccer 2018            SPORTS     4.6  9873470
# 3880                           Agar.io              GAME     4.2  3815614
# 8286                  DC Metro Transit  TRAVEL_AND_LOCAL     4.5      339
# 9808              HTC Sense Input - ES             TOOLS     4.3     3509
# 9460                            Ej-buy          BUSINESS     NaN        2
# 1941                      Major Mayhem              GAME     4.6   520962
# 3149   Despegar.com Hotels and Flights  TRAVEL_AND_LOCAL     4.4   150932
#
#                      Size      Installs  Type  Price Content Rating  \
# 4031   Varies with device  100,000,000+  Free      0           Teen
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
##Convert some of the objects into integer data type
##Remove duplicates

# %%
df.shape
# Out:
# (10841, 13)

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
##Change datatype of particular columns

# %%
df.describe(include='all').T
#For describing all the parameters
# Out:
#                  count unique                 top   freq      mean       std  \
# App              10841   9660              ROBLOX      9       NaN       NaN
# Category         10841     34              FAMILY   1972       NaN       NaN
# Rating          9367.0    NaN                 NaN    NaN  4.193338  0.537431
# Reviews          10841   6002                   0    596       NaN       NaN
# Size             10841    462  Varies with device   1695       NaN       NaN
# Installs         10841     22          1,000,000+   1579       NaN       NaN
# Type             10840      3                Free  10039       NaN       NaN
# Price            10841     93                   0  10040       NaN       NaN
# Content Rating   10840      6            Everyone   8714       NaN       NaN
# Genres           10841    120               Tools    842       NaN       NaN
# Last Updated     10841   1378      August 3, 2018    326       NaN       NaN
# ...

# %% [markdown]
# ## Cleaning Reviews column

# %%
df[['Reviews']]
# Out:
#       Reviews
# 0         159
# 1         967
# 2       87510
# 3      215644
# 4         967
# ...       ...
# 10836      38
# 10837       4
# 10838       3
# 10839     114
# 10840  398307
#
# [10841 rows x 1 columns]

# %%
df['Reviews'].shape
# Out:
# (10841,)

# %%
##Check if some other datatypes are there in revuews
df['Reviews'].str.isnumeric().sum()
# Out:
# 10840

# %%
##1 row has text data
df[~df['Reviews'].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#We have obtained the text data from review column

# %%
df_copy=df.copy()

# %%
df_copy=df_copy.drop(df_copy.index[10472])

# %%
df_copy.shape
# Out:
# (10840, 13)

# %%
##Change the datatype of reviews
df_copy["Reviews"]=df_copy["Reviews"].astype("int")

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Succesfully changed datatype of reviews by dropping one row

# %% [markdown]
# ## Cleaning up size

# %%
df_copy['Size']=df_copy['Size'].str.replace('M','000')

# %%
df_copy[['Size']]
# Out:
#                      Size
# 0                   19000
# 1                   14000
# 2                  8.7000
# 3                   25000
# 4                  2.8000
# ...                   ...
# 10836               53000
# 10837              3.6000
# 10838              9.5000
# 10839  Varies with device
# 10840               19000
#
# [10840 rows x 1 columns]

# %%
df_copy['Size']=df_copy['Size'].str.replace('k','')

# %%
df_copy['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'Varies with device', '9.4000', '15000', '10000',
#        '1.2000', '26000', '8.0000', '7.9000', '56000', '57000', '35000',
#        '54000', '201', '3.6000', '5.7000', '8.6000', '2.4000', '27000',
#        '2.5000', '16000', '3.4000', '8.9000', '3.9000', '2.9000', '38000',
#        '32000', '5.4000', '18000', '1.1000', '2.2000', '4.5000', '9.8000',
#        '52000', '9.0000', '6.7000', '30000', '2.6000', '7.1000', '3.7000',
#        '22000', '7.4000', '6.4000', '3.2000', '8.2000', '9.9000',
#        '4.9000', '9.5000', '5.0000', '5.9000', '13000', '73000', '6.8000',
#        '3.5000', '4.0000', '2.3000', '7.2000', '2.1000', '42000',
# ...

# %%
##Need to clean up one row

# %%
df_copy["Size"]=df_copy["Size"].str.replace("Varies with device", str(np.nan))

# %%
df_copy['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'nan', '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
df_copy['Size']=df_copy['Size'].astype('float')

# %%
df_copy['Size'].isnull().sum()
# Out:
# 1695

# %%
## Again in this dataset there are decimal values..We have to clean those up too

# %%
df_copy['Size'][2]*1000
# Out:
# 8700.0

# %%
for i in df_copy['Size']:
    if i<10:
        df_copy['Size']=df_copy['Size'].replace(i,i*1000)

# %%
df_copy['Size'].unique()
# Out:
# array([1.90e+04, 1.40e+04, 8.70e+03, 2.50e+04, 2.80e+03, 5.60e+03,
#        2.90e+04, 3.30e+04, 3.10e+03, 2.80e+04, 1.20e+04, 2.00e+04,
#        2.10e+04, 3.70e+04, 2.70e+03, 5.50e+03, 1.70e+04, 3.90e+04,
#        3.10e+04, 4.20e+03, 7.00e+03, 2.30e+04, 6.00e+03, 6.10e+03,
#        4.60e+03, 9.20e+03, 5.20e+03, 1.10e+04, 2.40e+04,      nan,
#        9.40e+03, 1.50e+04, 1.00e+04, 1.20e+03, 2.60e+04, 8.00e+03,
#        7.90e+03, 5.60e+04, 5.70e+04, 3.50e+04, 5.40e+04, 2.01e+02,
#        3.60e+03, 5.70e+03, 8.60e+03, 2.40e+03, 2.70e+04, 2.50e+03,
#        1.60e+04, 3.40e+03, 8.90e+03, 3.90e+03, 2.90e+03, 3.80e+04,
#        3.20e+04, 5.40e+03, 1.80e+04, 1.10e+03, 2.20e+03, 4.50e+03,
#        9.80e+03, 5.20e+04, 9.00e+03, 6.70e+03, 3.00e+04, 2.60e+03,
#        7.10e+03, 3.70e+03, 2.20e+04, 7.40e+03, 6.40e+03, 3.20e+03,
#        8.20e+03, 9.90e+03, 4.90e+03, 9.50e+03, 5.00e+03, 5.90e+03,
#        1.30e+04, 7.30e+04, 6.80e+03, 3.50e+03, 4.00e+03, 2.30e+03,
# ...

# %%
df_copy['Size']=df_copy['Size']/1000

# %%
df_copy['Size'].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01,      nan,
#        9.40e+00, 1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00,
#        7.90e+00, 5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e-01,
#        3.60e+00, 5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00,
#        1.60e+01, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01,
#        3.20e+01, 5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00,
#        7.10e+00, 3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00,
#        8.20e+00, 9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00,
#        1.30e+01, 7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00,
# ...

# %%
df_copy['Size']=df_copy['Size'].dropna()

# %%
df_copy['Size'].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01,      nan,
#        9.40e+00, 1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00,
#        7.90e+00, 5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e-01,
#        3.60e+00, 5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00,
#        1.60e+01, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01,
#        3.20e+01, 5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00,
#        7.10e+00, 3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00,
#        8.20e+00, 9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00,
#        1.30e+01, 7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00,
# ...

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159  19.0      10,000+  Free     0       Everyone
# 1      967  14.0     500,000+  Free     0       Everyone
# 2    87510   8.7   5,000,000+  Free     0       Everyone
# 3   215644  25.0  50,000,000+  Free     0           Teen
# 4      967   2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ## Now clean "install'' columns

# %%
df_copy['Installs'].dtype
# Out:
# dtype('O')

# %%
df_copy['Price'].dtype
# Out:
# dtype('O')

# %%
df_copy['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df_copy['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %% [markdown]
# ### Operation to clean installs and Price

# %%
chars_to_remove=['+',',','$']
cols_to_clean=['Price','Installs']
for item in chars_to_remove:
    for col in cols_to_clean:
        df_copy[col]=df_copy[col].str.replace(item,'')

# %%
df_copy['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df_copy['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df_copy['Installs']=df_copy['Installs'].astype('int')

# %%
df_copy['Price']=df_copy['Price'].astype('float')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int32(2), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Change 'Last Updated' column using time and date

# %%
df_copy['Last Updated']
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
df_copy['Last Updated']=pd.to_datetime(df_copy['Last Updated'])

# %%
df_copy['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10840, dtype: datetime64[ns]

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df_copy['Last Updated'].dt.day
# Out:
# 0         7
# 1        15
# 2         1
# 3         8
# 4        20
#          ..
# 10836    25
# 10837     6
# 10838    20
# 10839    19
# 10840    25
# Name: Last Updated, Length: 10840, dtype: int64

# %%
df_copy['Last Updated'].dt.month
# Out:
# 0        1
# 1        1
# 2        8
# 3        6
# 4        6
#         ..
# 10836    7
# 10837    7
# 10838    1
# 10839    1
# 10840    7
# Name: Last Updated, Length: 10840, dtype: int64

# %%
df_copy['Last Updated'].dt.year
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 10836    2017
# 10837    2018
# 10838    2017
# 10839    2015
# 10840    2018
# Name: Last Updated, Length: 10840, dtype: int64

# %%
df_copy['day']=df_copy['Last Updated'].dt.day
df_copy['month']=df_copy['Last Updated'].dt.month
df_copy['year']=df_copy['Last Updated'].dt.year

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy.to_csv("google_cleaned_2.csv",index=False)

# %%
pd.read_csv("google_cleaned_2.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df=pd.read_csv("google_cleaned_2.csv")

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3.6       100  Free    0.0       Everyone
# 10837     NaN        3   9.5      1000  Free    0.0       Everyone
# 10838     4.5      114   NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver         Android Ver  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# day                  0
# month                0
# year                 0
# dtype: int64

# %%
df.describe().T
# Out:
#             count          mean           std      min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.00     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.00    38.0    2094.0
# Size       9145.0  2.150653e+01  2.259602e+01     0.01     4.9      13.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.00  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.00     0.0       0.0
# day       10840.0  1.560904e+01  9.561621e+00     1.00     6.0      16.0
# month     10840.0  6.422325e+00  2.578388e+00     1.00     5.0       7.0
# year      10840.0  2.017400e+03  1.100914e+00  2010.00  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size           30.0  1.000000e+02
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# ...

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## EXPLORING THE DATA

# %%
numeric_features=[feature for feature in df.columns if df[feature].dtype !='O']
cat_features=[feature for feature in df.columns if df[feature].dtype =='O']

# %%
print("the numeric features are",numeric_features)
print('the categorical features are',cat_features)
# Out:
# the numeric features are ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']
# the categorical features are ['App', 'Category', 'Type', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
df['App'].value_counts(normalize=True)*100
# Out:
# ROBLOX                                           0.086898
# 8 Ball Pool                                      0.067587
# Bubble Shooter                                   0.057932
# Helix Jump                                       0.057932
# Zombie Catchers                                  0.057932
#                                                    ...
# Popsicle Launcher for Android P 9.0 launcher     0.009655
# PixelLab - Text on pictures                      0.009655
# P Launcher for Android™ 9.0                      0.009655
# Pacify (Android P theme) - Theme for Xperia™     0.009655
# iHoroscope - 2018 Daily Horoscope & Astrology    0.009655
# Name: App, Length: 9659, dtype: float64

# %% [markdown]
# ### Check dist of numeric variable

# %%
num_df=df[numeric_features]

# %%
num_df
# Out:
#        Rating  Reviews  Size  Installs  Price  day  month  year
# 0         4.1      159  19.0     10000    0.0    7      1  2018
# 1         3.9      967  14.0    500000    0.0   15      1  2018
# 2         4.7    87510   8.7   5000000    0.0    1      8  2018
# 3         4.5   215644  25.0  50000000    0.0    8      6  2018
# 4         4.3      967   2.8    100000    0.0   20      6  2018
# ...       ...      ...   ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53.0      5000    0.0   25      7  2017
# 10836     5.0        4   3.6       100    0.0    6      7  2018
# 10837     NaN        3   9.5      1000    0.0   20      1  2017
# 10838     4.5      114   NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19.0  10000000    0.0   25      7  2018
#
# [10357 rows x 8 columns]

# %%
for feature in num_df:
    sns.kdeplot(num_df[feature])
    plt.xlabel(feature)
    plt.ylabel('count')
    plt.title('Numerical_Features')
    plt.show()

# %%
cat_df=df[cat_features]

# %%
cat_df['Type'].value_counts()
# Out:
# Free    9591
# Paid     765
# Name: Type, dtype: int64

# %%
cat_df['Content Rating'].value_counts()
# Out:
# Everyone           8382
# Teen               1146
# Mature 17+          447
# Everyone 10+        377
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
sns.countplot(cat_df['Content Rating'])

# %%
plt.figure(figsize=(20,15))
plt.suptitle("Univariate Analysis of CAT Features",fontsize=20,fontweight='bold',alpha=0.8,y=1.01)
category=['Type','Content Rating']
for i in range(len(category)):
    plt.subplot(2,2,i+1)
    sns.countplot(x=df[category[i]])
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
cat_df['Category'].value_counts().plot.pie(figsize=(20,20),autopct='%1.0f%%')

# %% [markdown]
# ### Find the top 10 categories

# %%
Category=pd.DataFrame(cat_df['Category'].value_counts())

# %%
Category.head()
# Out:
#           Count
# FAMILY     1943
# GAME       1121
# TOOLS       843
# BUSINESS    427
# MEDICAL     408

# %%
Category.rename(columns={'Category':'Count'},inplace=True)

# %%
Category.head(10)
# Out:
#                  Count
# FAMILY            1943
# GAME              1121
# TOOLS              843
# BUSINESS           427
# MEDICAL            408
# PRODUCTIVITY       407
# PERSONALIZATION    388
# LIFESTYLE          373
# COMMUNICATION      366
# FINANCE            360

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=Category.index[:10],y='Count',data=Category[:10])

# %% [markdown]
# ### Which category has the largest no. of installations

# %%
df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   31544024415
# COMMUNICATION          24152276251
# SOCIAL                 12513867902
# PRODUCTIVITY           12463091369
# TOOLS                  11452771915
# FAMILY                 10041692505
# PHOTOGRAPHY             9721247655
# TRAVEL_AND_LOCAL        6361887146
# VIDEO_PLAYERS           6222002720
# NEWS_AND_MAGAZINES      5393217760
# SHOPPING                2573348785
# ENTERTAINMENT           2455660000
# PERSONALIZATION         2074494782
# BOOKS_AND_REFERENCE     1916469576
# SPORTS                  1528574498
# HEALTH_AND_FITNESS      1361022512
# BUSINESS                 863664865
# FINANCE                  770348734
# MAPS_AND_NAVIGATION      724281890
# LIFESTYLE                534823539
# EDUCATION                533952000
# WEATHER                  426100520
# FOOD_AND_DRINK           257898751
# DATING                   206536107
# HOUSE_AND_HOME           125212461
# ART_AND_DESIGN           124338100
# ...

# %%
df.groupby(['Category'])['Installs'].sum().nlargest(10).plot(kind='bar',figsize=(20,10))

# %% [markdown]
# ### How many apps are there on playstore which get 5 rating?

# %% [markdown]
# ### Does size of application has any impact on its popularity?

# %% [markdown]
# ### What are the top5 most installed apps in each popular category?

# %% [markdown]
# ### How many application are free and paid

# %%
df.value_counts('Type').plot(kind='pie',figsize=(5,5))

# %% [markdown]
# ### Which category app users are reviewing the most?

# %% [markdown]
# ### Which has more downloads with respect to free/paid?

# %% [markdown]
# ##    Linear Regression
